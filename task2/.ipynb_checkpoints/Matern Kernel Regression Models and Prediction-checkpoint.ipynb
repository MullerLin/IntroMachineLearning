# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import KNNImputer
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, RBF, Matern, RationalQuadratic
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

# %%
from tqdm import tqdm
import time

# %% [markdown]
# # Data Load

# %%
def data_loading():
    """
    This function loads the training and test data, preprocesses it, removes the NaN values and interpolates the missing 
    data using imputation

    Parameters
    ----------
    Returns
    ----------
    X_train: matrix of floats, training input with features
    y_train: array of floats, training output with labels
    X_test: matrix of floats: dim = (100, ?), test input with features
    """
    # Load training data
    train_df = pd.read_csv("train.csv")
    
    print("Training data:")
    print("Shape:", train_df.shape)
    print(train_df.head(2))
    print('\n')
    
    # Load test data
    test_df = pd.read_csv("test.csv")

    print("Test data:")
    print(test_df.shape)
    print(test_df.head(2))

    # Dummy initialization of the X_train, X_test and y_train   
    X_train = np.zeros_like(train_df.drop(['price_CHF'],axis=1))
    y_train = np.zeros_like(train_df['price_CHF'])
    X_test = np.zeros_like(test_df)

    # TODO: Perform data preprocessing, imputation and extract X_train, y_train and X_test
    train_arr = np.array(train_df)
    test_arr = np.array(test_df)
    
    # one hot encoder
    train_arr = np.array(train_df)
    test_arr = np.array(test_df)
    
    # one hot encoder
    column_to_encode = 0
    train_to_encode = train_arr[:, column_to_encode].reshape(-1, 1)
    test_to_encode = test_arr[:, column_to_encode].reshape(-1, 1)
    encoder = OneHotEncoder()
    encoder.fit(train_to_encode)
    encoded_train_data = encoder.transform(train_to_encode)
    encoded_train_arr = np.concatenate((train_arr[:, :column_to_encode],
                            encoded_train_data.toarray(),
                            train_arr[:, column_to_encode+1:]), axis=1)
    
    encoded_test_data = encoder.transform(test_to_encode)
    encoded_test_arr = np.concatenate((test_arr[:, :column_to_encode],
                            encoded_test_data.toarray(),
                            test_arr[:, column_to_encode+1:]),axis=1)
    
    # KNN Imputer
    imputer = KNNImputer(n_neighbors=15, weights = 'uniform')
    imputed_train = imputer.fit_transform(encoded_train_arr)
    imputed_test = imputer.fit_transform(encoded_test_arr)
    
    # delete the price of electric of swi
    train_idx = [i for i in range(encoded_train_arr.shape[0]) if np.isnan(encoded_train_arr[i,5]) == False] 
    imputed_train_refined = imputed_train[train_idx]
    
    X_train = np.delete(imputed_train_refined, 5, 1)
    y_train = imputed_train_refined[:, 5]
    
    X_test = imputed_test
    
    assert (X_train.shape[1] == X_test.shape[1]) and (X_train.shape[0] == y_train.shape[0]) and (X_test.shape[0] == 100), "Invalid data shape"
    return X_train, y_train, X_test

# %%
X_train, y_train, X_test = data_loading()
# Out:
# Training data:
# Shape: (900, 11)
#    season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0  spring        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1  summer        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
#
#    price_UK  price_ITA  price_POL  price_SVK
# 0 -1.822720  -3.931031        NaN  -3.238197
# 1 -1.826021        NaN        NaN  -3.212894
#
#
# Test data:
# (100, 10)
#    season  price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  \
# 0  spring        NaN   0.472985   0.707957        NaN  -1.136441 -0.596703
# 1  summer  -1.184837   0.358019        NaN  -3.199028  -1.069695       NaN
#
#    price_ITA  price_POL  price_SVK
# 0        NaN   3.298693   1.921886
# 1  -1.420091   3.238307        NaN

# %% [markdown]
# # Model Test and Optimize

# %% [markdown]
# ## Kernel Optimization

# %% [markdown]
# ### Matern Kernel

# %%
ls_range = np.logspace(-5, 1, 100, base=10)
nu_range = np.logspace(-5, 1, 100, base=10)

# %%
params = [  (0.05, 0.5), (0.05, 1.5), (0.05, 2.5),
                (0.1, 0.5), (0.1, 1.5), (0.1, 2.5),
                (1, 0.5), (1, 1.5), (1, 2.5)]
for i in range (len(ls_range)):
    for j in range (len(nu_range)):
        params.append((ls_range[i], nu_range[j]))

# %%
def Matern_para_select(X, y, n_folds):
    print("————Matern————")
    ls_range = np.logspace(-2, 0.5, 10, base=10)
    nu_range = np.logspace(-2, 0.5, 10, base=10)
    params = [  (0.05, 0.5), (0.05, 1.5), (0.05, 2.5),
                (0.1, 0.5), (0.1, 1.5), (0.1, 2.5),
                (1, 0.5), (1, 1.5), (1, 2.5)]
    for i in range (len(ls_range)):
        for j in range (len(nu_range)):
            params.append((ls_range[i], nu_range[j]))
    pbar = tqdm(total=len(params)*n_folds)
    R2score_mat = np.zeros((n_folds, len(params)))
    kf = KFold(n_splits=n_folds, shuffle=True, random_state= 14)
    for fold_idx, (train, test) in enumerate(kf.split(X)):
        X_train, X_val, y_train, y_val = X[train], X[test], y[train], y[test]
        for idx, (ls, nu) in enumerate(params):
            gpr = GaussianProcessRegressor(kernel= Matern(length_scale=ls, nu=nu))
            gpr.fit(X_train, y_train)
            y_val_pred = gpr.predict(X_val)
            R2score_mat[fold_idx][idx] = r2_score(y_val, y_val_pred)
            pbar.update()
    pbar.close()
    
    avg_R2score = np.mean(R2score_mat, axis=0)
    print("Best Param: ", params[np.argmax([avg_R2score])], " Score: ", avg_R2score[np.argmax([avg_R2score])])
    print(avg_R2score)
    print("______________end_____________")
    return avg_R2score, params[np.argmax([avg_R2score])]

# %%
n_folds = 10
avg_R2score_M, best_para_M = Matern_para_select(X_train, y_train, n_folds)
# Out:
#   0%|                                                   | 0/109 [00:00<?, ?it/s]
#
#
#   2%|▊                                          | 2/109 [00:00<00:09, 11.10it/s]
# ————Matern————
#   3%|█▏                                         | 3/109 [00:00<00:10,  9.94it/s]
#
#
#   5%|█▉                                         | 5/109 [00:00<00:09, 10.74it/s]
#
#
#   6%|██▊                                        | 7/109 [00:00<00:08, 11.49it/s]
#
#
#   8%|███▌                                       | 9/109 [00:00<00:08, 11.96it/s]
#
#
#  10%|████▏                                     | 11/109 [00:03<00:48,  2.00it/s]
#
#
#  11%|████▌                                     | 12/109 [00:05<01:21,  1.19it/s]
#
#
#  12%|█████                                     | 13/109 [00:06<01:30,  1.06it/s]
#
#
#  13%|█████▍                                    | 14/109 [00:09<02:29,  1.57s/it]
#
#
#  14%|█████▊                                    | 15/109 [00:11<02:49,  1.80s/it]
#
#
#  15%|██████▏                                   | 16/109 [00:12<02:04,  1.34s/it]
#
#
#  16%|██████▌                                   | 17/109 [00:12<01:34,  1.02s/it]
#
#
#  17%|██████▉                                   | 18/109 [00:12<01:11,  1.28it/s]
#
#
#  17%|███████▎                                  | 19/109 [00:12<00:53,  1.68it/s]
#
#
#  18%|███████▋                                  | 20/109 [00:14<01:20,  1.11it/s]
#
#
#  19%|████████                                  | 21/109 [00:16<01:43,  1.18s/it]
#
#
#  20%|████████▍                                 | 22/109 [00:18<02:16,  1.57s/it]
#
#
#  21%|████████▊                                 | 23/109 [00:20<02:24,  1.68s/it]
#
#
#  22%|█████████▏                                | 24/109 [00:22<02:18,  1.63s/it]
#
#
#  23%|█████████▋                                | 25/109 [00:23<02:19,  1.66s/it]
#
#
#  24%|██████████                                | 26/109 [00:26<02:33,  1.85s/it]
#
#
#  25%|██████████▍                               | 27/109 [00:30<03:42,  2.71s/it]
#
#
#  26%|██████████▊                               | 28/109 [00:32<03:19,  2.46s/it]
#
#
#  27%|███████████▏                              | 29/109 [00:37<04:19,  3.25s/it]
#
#
#  28%|███████████▌                              | 30/109 [00:39<03:36,  2.74s/it]
#
#
#  28%|███████████▉                              | 31/109 [00:41<03:10,  2.44s/it]
#
#
#  29%|████████████▎                             | 32/109 [00:42<02:52,  2.24s/it]
#
#
#  30%|████████████▋                             | 33/109 [00:44<02:24,  1.90s/it]
#
#
#  31%|█████████████                             | 34/109 [00:45<02:03,  1.65s/it]
#
#
#  32%|█████████████▍                            | 35/109 [00:46<02:02,  1.66s/it]
#
#
#  33%|█████████████▊                            | 36/109 [00:49<02:13,  1.83s/it]
#
#
#  34%|██████████████▎                           | 37/109 [00:51<02:25,  2.03s/it]
#
#
#  35%|██████████████▋                           | 38/109 [00:54<02:38,  2.23s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
#  36%|███████████████                           | 39/109 [00:57<03:05,  2.65s/it]
#
#
#  37%|███████████████▍                          | 40/109 [00:59<02:38,  2.30s/it]
#
#
#  38%|███████████████▊                          | 41/109 [01:01<02:37,  2.31s/it]
#
#
#  39%|████████████████▏                         | 42/109 [01:04<02:43,  2.44s/it]
#
#
#  39%|████████████████▌                         | 43/109 [01:05<02:17,  2.08s/it]
#
#
#  40%|████████████████▉                         | 44/109 [01:06<01:59,  1.84s/it]
#
#
#  41%|█████████████████▎                        | 45/109 [01:08<01:43,  1.61s/it]
#
#
#  42%|█████████████████▋                        | 46/109 [01:09<01:42,  1.63s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
#  43%|██████████████████                        | 47/109 [01:16<03:16,  3.17s/it]
#
#
#  44%|██████████████████▍                       | 48/109 [01:18<02:50,  2.80s/it]
#
#
#  45%|██████████████████▉                       | 49/109 [01:21<02:52,  2.87s/it]
#
#
#  46%|███████████████████▎                      | 50/109 [01:23<02:29,  2.53s/it]
#
#
#  47%|███████████████████▋                      | 51/109 [01:24<02:14,  2.31s/it]
#
#
#  48%|████████████████████                      | 52/109 [01:26<01:57,  2.05s/it]
#
#
#  49%|████████████████████▍                     | 53/109 [01:27<01:45,  1.88s/it]
#
#
#  50%|████████████████████▊                     | 54/109 [01:29<01:41,  1.84s/it]
#
#
#  50%|█████████████████████▏                    | 55/109 [01:30<01:31,  1.69s/it]
#
#
#  51%|█████████████████████▌                    | 56/109 [01:32<01:30,  1.70s/it]
#
#
#  52%|█████████████████████▉                    | 57/109 [01:34<01:23,  1.60s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
#  53%|██████████████████████▎                   | 58/109 [01:40<02:35,  3.05s/it]
#
#
#  54%|██████████████████████▋                   | 59/109 [01:44<02:51,  3.44s/it]
#
#
#  55%|███████████████████████                   | 60/109 [01:46<02:20,  2.87s/it]
#
#
#  56%|███████████████████████▌                  | 61/109 [01:48<02:04,  2.60s/it]
#
#
#  57%|███████████████████████▉                  | 62/109 [01:51<02:03,  2.64s/it]
#
#
#  58%|████████████████████████▎                 | 63/109 [01:52<01:42,  2.23s/it]
#
#
#  59%|████████████████████████▋                 | 64/109 [01:54<01:37,  2.16s/it]
#
#
#  60%|█████████████████████████                 | 65/109 [01:55<01:22,  1.88s/it]
#
#
#  61%|█████████████████████████▍                | 66/109 [01:57<01:25,  1.99s/it]
#
#
#  61%|█████████████████████████▊                | 67/109 [02:00<01:32,  2.21s/it]
#
#
#  62%|██████████████████████████▏               | 68/109 [02:03<01:44,  2.54s/it]
#
#
#  63%|██████████████████████████▌               | 69/109 [02:06<01:38,  2.46s/it]
#
#
#  64%|██████████████████████████▉               | 70/109 [02:07<01:26,  2.23s/it]
#
#
#  65%|███████████████████████████▎              | 71/109 [02:09<01:20,  2.13s/it]
#
#
#  66%|███████████████████████████▋              | 72/109 [02:10<01:09,  1.87s/it]
#
#
#  67%|████████████████████████████▏             | 73/109 [02:12<01:01,  1.70s/it]
#
#
#  68%|████████████████████████████▌             | 74/109 [02:13<00:55,  1.58s/it]
#
#
#  69%|████████████████████████████▉             | 75/109 [02:14<00:50,  1.48s/it]
#
#
#  70%|█████████████████████████████▎            | 76/109 [02:17<01:04,  1.95s/it]
#
#
#  71%|█████████████████████████████▋            | 77/109 [02:19<00:59,  1.86s/it]
#
#
#  72%|██████████████████████████████            | 78/109 [02:21<00:59,  1.93s/it]
#
#
#  72%|██████████████████████████████▍           | 79/109 [02:25<01:13,  2.44s/it]
#
#
#  73%|██████████████████████████████▊           | 80/109 [02:26<01:00,  2.10s/it]
#
#
#  74%|███████████████████████████████▏          | 81/109 [02:28<00:55,  2.00s/it]
#
#
#  75%|███████████████████████████████▌          | 82/109 [02:29<00:50,  1.89s/it]
#  76%|███████████████████████████████▉          | 83/109 [02:31<00:48,  1.87s/it]
#
#
#  77%|████████████████████████████████▎         | 84/109 [02:32<00:41,  1.67s/it]
#
#
#  78%|████████████████████████████████▊         | 85/109 [02:34<00:36,  1.53s/it]
#
#
#  79%|█████████████████████████████████▏        | 86/109 [02:36<00:38,  1.67s/it]
#
#
#  80%|█████████████████████████████████▌        | 87/109 [02:37<00:36,  1.64s/it]
#
#
#  81%|█████████████████████████████████▉        | 88/109 [02:40<00:40,  1.94s/it]
#
#
#  82%|██████████████████████████████████▎       | 89/109 [02:41<00:35,  1.79s/it]
#
#
#  83%|██████████████████████████████████▋       | 90/109 [02:43<00:32,  1.70s/it]
#
#
#  83%|███████████████████████████████████       | 91/109 [02:44<00:29,  1.64s/it]
#
#
#  84%|███████████████████████████████████▍      | 92/109 [02:46<00:25,  1.52s/it]
#
#
#  85%|███████████████████████████████████▊      | 93/109 [02:47<00:22,  1.41s/it]
#
#
#  86%|████████████████████████████████████▏     | 94/109 [02:48<00:20,  1.36s/it]
#
#
#  87%|████████████████████████████████████▌     | 95/109 [02:49<00:17,  1.26s/it]
#
#
#  88%|████████████████████████████████████▉     | 96/109 [02:50<00:16,  1.28s/it]
#
#
#  89%|█████████████████████████████████████▍    | 97/109 [02:52<00:16,  1.34s/it]
#
#
#  90%|█████████████████████████████████████▊    | 98/109 [02:53<00:14,  1.33s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
#  91%|██████████████████████████████████████▏   | 99/109 [02:53<00:10,  1.00s/it]
#
#
#  92%|█████████████████████████████████████▌   | 100/109 [02:55<00:09,  1.09s/it]
#
#
#  93%|█████████████████████████████████████▉   | 101/109 [02:56<00:09,  1.16s/it]
#
#
#  94%|██████████████████████████████████████▎  | 102/109 [02:57<00:08,  1.25s/it]
#
#
#  94%|██████████████████████████████████████▋  | 103/109 [02:59<00:07,  1.22s/it]
#
#
#  95%|███████████████████████████████████████  | 104/109 [03:00<00:06,  1.21s/it]
#
#
#  96%|███████████████████████████████████████▍ | 105/109 [03:01<00:04,  1.16s/it]
#
#
#  97%|███████████████████████████████████████▊ | 106/109 [03:02<00:03,  1.10s/it]
#
#
#  98%|████████████████████████████████████████▏| 107/109 [03:04<00:02,  1.43s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
#  99%|████████████████████████████████████████▌| 108/109 [03:04<00:01,  1.07s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 100%|█████████████████████████████████████████| 109/109 [03:04<00:00,  1.22it/s]
#
#
# 111it [03:05,  1.69it/s]
#
#
# 112it [03:05,  2.22it/s]
#
#
# 114it [03:05,  2.95it/s]
#
#
# 116it [03:05,  3.84it/s]
#
#
# 118it [03:05,  4.88it/s]
#
#
# 120it [03:09,  1.54it/s]
#
#
# 121it [03:10,  1.18it/s]
#
#
# 122it [03:11,  1.05it/s]
#
#
# 123it [03:12,  1.08s/it]
#
#
# 124it [03:14,  1.25s/it]
#
#
# 125it [03:14,  1.05it/s]
#
#
# 126it [03:15,  1.30it/s]
#
#
# 127it [03:15,  1.66it/s]
#
#
# 128it [03:15,  2.15it/s]
#
#
# 129it [03:16,  1.34it/s]
#
#
# 130it [03:18,  1.00it/s]
#
#
# 131it [03:19,  1.07s/it]
#
#
# 132it [03:20,  1.12s/it]
#
#
# 133it [03:22,  1.11s/it]
#
#
# 134it [03:23,  1.14s/it]
#
#
# 135it [03:25,  1.59s/it]
#
#
# 136it [03:27,  1.73s/it]
#
#
# 137it [03:31,  2.23s/it]
#
#
# 138it [03:34,  2.44s/it]
#
#
# 139it [03:35,  2.14s/it]
#
#
# 140it [03:37,  2.00s/it]
#
#
# 141it [03:38,  1.78s/it]
#
#
# 142it [03:39,  1.61s/it]
#
#
# 143it [03:40,  1.39s/it]
#
#
# 144it [03:41,  1.32s/it]
#
#
# 145it [03:43,  1.54s/it]
#
#
# 146it [03:46,  1.72s/it]
#
#
# 147it [03:47,  1.74s/it]
#
#
# 148it [03:52,  2.60s/it]
#
#
# 149it [03:54,  2.28s/it]
#
#
# 150it [03:55,  2.11s/it]
#
#
# 151it [03:57,  2.00s/it]
#
#
# 152it [03:58,  1.78s/it]
#
#
# 153it [03:59,  1.59s/it]
#
#
# 154it [04:01,  1.55s/it]
#
#
# 155it [04:05,  2.21s/it]
#
#
# 156it [04:11,  3.48s/it]
#
#
# 157it [04:13,  2.98s/it]
#
#
# 158it [04:16,  2.94s/it]
#
#
# 159it [04:17,  2.54s/it]
#
#
# 160it [04:19,  2.26s/it]
#
#
# 161it [04:20,  1.98s/it]
#
#
# 162it [04:21,  1.75s/it]
#
#
# 163it [04:23,  1.64s/it]
#
#
# 164it [04:24,  1.50s/it]
#
#
# 165it [04:26,  1.51s/it]
#
#
# 166it [04:27,  1.64s/it]
#
#
# 167it [04:29,  1.74s/it]
#
#
# 168it [04:33,  2.40s/it]
#
#
# 169it [04:35,  2.12s/it]
#
#
# 170it [04:37,  2.02s/it]
#
#
# 171it [04:38,  1.94s/it]
#
#
# 172it [04:40,  1.73s/it]
#
#
# 173it [04:41,  1.59s/it]
#
#
# 174it [04:42,  1.56s/it]
#
#
# 175it [04:44,  1.56s/it]
#
#
# 176it [04:46,  1.72s/it]
#
#
# 177it [04:47,  1.63s/it]
#
#
# 178it [04:50,  1.92s/it]
#
#
# 179it [04:52,  1.85s/it]
#
#
# 180it [04:53,  1.79s/it]
#
#
# 181it [04:55,  1.63s/it]
#
#
# 182it [04:56,  1.54s/it]
#
#
# 183it [04:57,  1.48s/it]
#
#
# 184it [04:59,  1.58s/it]
#
#
# 185it [05:01,  1.60s/it]
#
#
# 186it [05:02,  1.62s/it]
#
#
# 187it [05:04,  1.62s/it]
#
#
# 188it [05:07,  2.08s/it]
#
#
# 189it [05:09,  1.85s/it]
#
#
# 190it [05:10,  1.79s/it]
#
#
# 191it [05:12,  1.74s/it]
#
#
# 192it [05:13,  1.69s/it]
#
#
# 193it [05:15,  1.68s/it]
#
#
# 194it [05:16,  1.54s/it]
#
#
# 195it [05:19,  2.04s/it]
#
#
# 196it [05:21,  1.88s/it]
#
#
# 197it [05:23,  1.85s/it]
#
#
# 198it [05:24,  1.72s/it]
#
#
# 199it [05:26,  1.67s/it]
#
#
# 200it [05:27,  1.61s/it]
#
#
# 201it [05:28,  1.49s/it]
#
#
# 202it [05:30,  1.46s/it]
#
#
# 203it [05:31,  1.46s/it]
#
#
# 204it [05:32,  1.33s/it]
#
#
# 205it [05:34,  1.32s/it]
#
#
# 206it [05:35,  1.22s/it]
#
#
# 207it [05:36,  1.15s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 208it [05:36,  1.15it/s]
#
#
# 209it [05:37,  1.04it/s]
#
#
# 210it [05:39,  1.16s/it]
#
#
# 211it [05:40,  1.28s/it]
#
#
# 212it [05:41,  1.24s/it]
#
#
# 213it [05:42,  1.15s/it]
#
#
# 214it [05:43,  1.08s/it]
#
#
# 215it [05:44,  1.01it/s]
#
#
# 216it [05:46,  1.29s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 217it [05:46,  1.03it/s]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 218it [05:46,  1.34it/s]
#
#
# 220it [05:47,  1.81it/s]
#
#
# 221it [05:47,  2.35it/s]
#
#
# 223it [05:47,  3.09it/s]
#
#
# 225it [05:47,  4.03it/s]
#
#
# 227it [05:47,  5.17it/s]
#
#
# 229it [05:50,  1.79it/s]
#
#
# 230it [05:51,  1.20it/s]
#
#
# 231it [05:53,  1.02it/s]
#
#
# 232it [05:54,  1.12s/it]
#
#
# 233it [05:56,  1.43s/it]
#
#
# 234it [05:57,  1.08s/it]
#
#
# 235it [05:57,  1.20it/s]
#
#
# 236it [05:57,  1.59it/s]
#
#
# 237it [05:57,  2.11it/s]
#
#
# 238it [05:58,  1.36it/s]
#
#
# 239it [06:00,  1.15it/s]
#
#
# 240it [06:01,  1.05s/it]
#
#
# 241it [06:03,  1.18s/it]
#
#
# 242it [06:04,  1.18s/it]
#
#
# 243it [06:05,  1.17s/it]
#
#
# 244it [06:07,  1.34s/it]
#
#
# 245it [06:11,  2.12s/it]
#
#
# 246it [06:13,  2.19s/it]
#
#
# 247it [06:13,  1.61s/it]
#
#
# 248it [06:15,  1.56s/it]
#
#
# 249it [06:16,  1.56s/it]
#
#
# 250it [06:18,  1.52s/it]
#
#
# 251it [06:19,  1.41s/it]
#
#
# 252it [06:20,  1.30s/it]
#
#
# 253it [06:22,  1.44s/it]
#
#
# 254it [06:24,  1.83s/it]
#
#
# 255it [06:26,  1.91s/it]
#
#
# 256it [06:29,  2.20s/it]
#
#
# 257it [06:35,  3.24s/it]
#
#
# 258it [06:37,  2.82s/it]
#
#
# 259it [06:39,  2.49s/it]
#
#
# 260it [06:40,  2.29s/it]
#
#
# 261it [06:43,  2.40s/it]
#
#
# 262it [06:45,  2.24s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 263it [06:51,  3.28s/it]
#
#
# 264it [06:52,  2.78s/it]
#
#
# 265it [06:54,  2.45s/it]
#
#
# 266it [06:56,  2.39s/it]
#
#
# 267it [07:00,  2.78s/it]
#
#
# 268it [07:01,  2.44s/it]
#
#
# 269it [07:03,  2.23s/it]
#
#
# 270it [07:05,  1.99s/it]
#
#
# 271it [07:07,  2.08s/it]
#
#
# 272it [07:09,  1.98s/it]
#
#
# 273it [07:10,  1.74s/it]
#
#
# 274it [07:12,  1.74s/it]
#
#
# 275it [07:13,  1.76s/it]
#
#
# 276it [07:17,  2.24s/it]
#
#
# 277it [07:20,  2.43s/it]
#
#
# 278it [07:21,  2.13s/it]
#
#
# 279it [07:23,  2.02s/it]
#
#
# 280it [07:27,  2.63s/it]
#
#
# 281it [07:28,  2.23s/it]
#
#
# 282it [07:30,  2.09s/it]
#
#
# 283it [07:31,  1.82s/it]
#
#
# 284it [07:33,  1.74s/it]
#
#
# 285it [07:37,  2.40s/it]
#
#
# 286it [07:40,  2.66s/it]
#
#
# 287it [07:42,  2.61s/it]
#
#
# 288it [07:44,  2.31s/it]
#
#
# 289it [07:46,  2.15s/it]
#
#
# 290it [07:47,  1.92s/it]
#
#
# 291it [07:48,  1.74s/it]
#
#
# 292it [07:50,  1.57s/it]
#
#
# 293it [07:51,  1.48s/it]
#
#
# 294it [07:53,  1.57s/it]
#
#
# 295it [07:54,  1.51s/it]
#
#
# 296it [07:56,  1.62s/it]
#
#
# 297it [07:58,  1.78s/it]
#
#
# 298it [07:59,  1.64s/it]
#
#
# 299it [08:01,  1.68s/it]
#
#
# 300it [08:03,  1.67s/it]
#
#
# 301it [08:04,  1.56s/it]
#
#
# 302it [08:06,  1.76s/it]
#
#
# 303it [08:08,  1.61s/it]
#
#
# 304it [08:10,  1.71s/it]
#
#
# 305it [08:13,  2.20s/it]
#
#
# 306it [08:15,  2.08s/it]
#
#
# 307it [08:17,  2.26s/it]
#
#
# 308it [08:19,  1.99s/it]
#
#
# 309it [08:20,  1.84s/it]
#
#
# 310it [08:22,  1.67s/it]
#
#
# 311it [08:23,  1.52s/it]
#
#
# 312it [08:24,  1.51s/it]
#
#
# 313it [08:25,  1.36s/it]
#
#
# 314it [08:26,  1.34s/it]
#
#
# 315it [08:29,  1.75s/it]
#
#
# 316it [08:31,  1.68s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 317it [08:31,  1.25s/it]
#
#
# 318it [08:32,  1.23s/it]
#
#
# 319it [08:34,  1.29s/it]
#
#
# 320it [08:35,  1.48s/it]
#
#
# 321it [08:37,  1.45s/it]
#
#
# 322it [08:38,  1.29s/it]
#
#
# 323it [08:39,  1.16s/it]
#
#
# 324it [08:40,  1.07s/it]
#
#
# 325it [08:41,  1.15s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 326it [08:41,  1.14it/s]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 327it [08:41,  1.43it/s]
#
#
# 329it [08:42,  1.93it/s]
#
#
# 330it [08:42,  2.47it/s]
#
#
# 332it [08:42,  3.23it/s]
#
#
# 334it [08:42,  4.16it/s]
#
#
# 336it [08:42,  5.17it/s]
#
#
# 337it [08:43,  2.01it/s]
#
#
# 338it [08:45,  1.32it/s]
#
#
# 339it [08:47,  1.05s/it]
#
#
# 340it [08:48,  1.13s/it]
#
#
# 341it [08:50,  1.47s/it]
#
#
# 342it [08:53,  1.91s/it]
#
#
# 343it [08:53,  1.41s/it]
#
#
# 344it [08:54,  1.07s/it]
#
#
# 345it [08:54,  1.26it/s]
#
#
# 346it [08:54,  1.70it/s]
#
#
# 347it [08:55,  1.24it/s]
#
#
# 348it [08:56,  1.07it/s]
#
#
# 349it [08:58,  1.10s/it]
#
#
# 350it [08:59,  1.19s/it]
#
#
# 351it [09:00,  1.17s/it]
#
#
# 352it [09:03,  1.61s/it]
#
#
# 353it [09:07,  2.30s/it]
#
#
# 354it [09:09,  2.17s/it]
#
#
# 355it [09:11,  2.09s/it]
#
#
# 356it [09:14,  2.55s/it]
#
#
# 357it [09:16,  2.24s/it]
#
#
# 358it [09:17,  2.04s/it]
#
#
# 359it [09:19,  1.83s/it]
#
#
# 360it [09:20,  1.61s/it]
#
#
# 361it [09:21,  1.55s/it]
#
#
# 362it [09:22,  1.36s/it]
#
#
# 363it [09:24,  1.53s/it]
#
#
# 364it [09:26,  1.72s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 365it [09:29,  2.14s/it]
#
#
# 366it [09:33,  2.52s/it]
#
#
# 367it [09:34,  2.19s/it]
#
#
# 368it [09:36,  2.06s/it]
#
#
# 369it [09:37,  1.85s/it]
#
#
# 370it [09:39,  1.67s/it]
#
#
# 371it [09:40,  1.67s/it]
#
#
# 372it [09:41,  1.49s/it]
#
#
# 373it [09:45,  2.09s/it]
#
#
# 374it [09:46,  1.90s/it]
#
#
# 375it [09:49,  2.12s/it]
#
#
# 376it [09:51,  2.23s/it]
#
#
# 377it [09:53,  2.06s/it]
#
#
# 378it [09:55,  1.94s/it]
#
#
# 379it [09:56,  1.76s/it]
#
#
# 380it [09:58,  1.69s/it]
#
#
# 381it [09:59,  1.76s/it]
#
#
# 382it [10:01,  1.60s/it]
#
#
# 383it [10:02,  1.66s/it]
#
#
# 384it [10:04,  1.69s/it]
#
#
# 385it [10:06,  1.83s/it]
#
#
# 386it [10:09,  2.18s/it]
#
#
# 387it [10:11,  1.97s/it]
#
#
# 388it [10:13,  1.92s/it]
#
#
# 389it [10:15,  1.99s/it]
#
#
# 390it [10:16,  1.77s/it]
#
#
# 391it [10:18,  1.74s/it]
#
#
# 392it [10:20,  1.85s/it]
#
#
# 393it [10:22,  2.08s/it]
#
#
# 394it [10:24,  2.01s/it]
#
#
# 395it [10:27,  2.33s/it]
#
#
# 396it [10:31,  2.69s/it]
#
#
# 397it [10:33,  2.39s/it]
#
#
# 398it [10:34,  2.20s/it]
#
#
# 399it [10:36,  1.93s/it]
#
#
# 400it [10:37,  1.75s/it]
#
#
# 401it [10:38,  1.62s/it]
#
#
# 402it [10:40,  1.74s/it]
#
#
# 403it [10:42,  1.69s/it]
#
#
# 404it [10:43,  1.58s/it]
#
#
# 405it [10:46,  1.88s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# 406it [10:55,  3.93s/it]
#
#
# 407it [10:56,  3.14s/it]
#
#
# 408it [10:58,  2.69s/it]
#
#
# 409it [10:59,  2.38s/it]
#
#
# 410it [11:01,  2.10s/it]
#
#
# 411it [11:02,  1.80s/it]
#
#
# 412it [11:04,  1.97s/it]
#
#
# 413it [11:06,  1.87s/it]
#
#
# 414it [11:07,  1.78s/it]
#
#
# 415it [11:09,  1.77s/it]
#
#
# 416it [11:10,  1.68s/it]
#
#
# 417it [11:12,  1.72s/it]
#
#
# 418it [11:14,  1.65s/it]
#
#
# 419it [11:15,  1.53s/it]
#
#
# 420it [11:16,  1.42s/it]
#
#
# 421it [11:19,  1.69s/it]
#
#
# 422it [11:20,  1.49s/it]
#
#
# 423it [11:21,  1.44s/it]
#
#
# 424it [11:22,  1.32s/it]
#
#
# 425it [11:25,  1.75s/it]
#
#
# 426it [11:28,  2.21s/it]
#
#
# 427it [11:29,  1.92s/it]
#
#
# 428it [11:31,  1.78s/it]
#
#
# 429it [11:33,  1.90s/it]
#
#
# 430it [11:34,  1.69s/it]
#
#
# 431it [11:35,  1.57s/it]
#
#
# 432it [11:36,  1.39s/it]
#
#
# 433it [11:39,  1.69s/it]
#
#
# 434it [11:41,  1.85s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 435it [11:41,  1.36s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 436it [11:41,  1.02s/it]
#
#
# 438it [11:41,  1.36it/s]
#
#
# 439it [11:42,  1.82it/s]
#
#
# 441it [11:42,  2.47it/s]
#
#
# 443it [11:42,  3.31it/s]
#
#
# 445it [11:42,  4.34it/s]
#
#
# 447it [11:44,  1.87it/s]
#
#
# 448it [11:46,  1.34it/s]
#
#
# 449it [11:47,  1.13it/s]
#
#
# 450it [11:48,  1.02s/it]
#
#
# 451it [11:50,  1.34s/it]
#
#
# 452it [11:51,  1.02s/it]
#
#
# 453it [11:51,  1.22it/s]
#
#
# 454it [11:51,  1.61it/s]
#
#
# 455it [11:51,  2.06it/s]
#
#
# 456it [11:53,  1.33it/s]
#
#
# 457it [11:54,  1.11it/s]
#
#
# 458it [11:55,  1.11s/it]
#
#
# 459it [11:57,  1.19s/it]
#
#
# 460it [12:02,  2.23s/it]
#
#
# 461it [12:02,  1.80s/it]
#
#
# 462it [12:06,  2.27s/it]
#
#
# 463it [12:10,  2.79s/it]
#
#
# 464it [12:14,  3.19s/it]
#
#
# 465it [12:17,  3.20s/it]
#
#
# 466it [12:19,  2.68s/it]
#
#
# 467it [12:20,  2.37s/it]
#
#
# 468it [12:21,  2.06s/it]
#
#
# 469it [12:23,  1.78s/it]
#
#
# 470it [12:27,  2.63s/it]
#
#
# 471it [12:28,  2.13s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 472it [12:36,  3.86s/it]
#
#
# 473it [12:38,  3.28s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 474it [12:44,  4.22s/it]
#
#
# 475it [12:49,  4.41s/it]
#
#
# 476it [12:51,  3.55s/it]
#
#
# 477it [12:53,  3.04s/it]
#
#
# 478it [12:54,  2.64s/it]
#
#
# 479it [12:56,  2.24s/it]
#
#
# 480it [13:00,  2.85s/it]
#
#
# 481it [13:01,  2.32s/it]
#
#
# 482it [13:03,  2.13s/it]
#
#
# 483it [13:04,  1.92s/it]
#
#
# 484it [13:06,  2.04s/it]
#
#
# 485it [13:08,  1.96s/it]
#
#
# 486it [13:10,  1.89s/it]
#
#
# 487it [13:12,  1.80s/it]
#
#
# 488it [13:13,  1.66s/it]
#
#
# 489it [13:14,  1.62s/it]
#
#
# 490it [13:16,  1.68s/it]
#
#
# 491it [13:18,  1.57s/it]
#
#
# 492it [13:22,  2.36s/it]
#
#
# 493it [13:23,  2.09s/it]
#
#
# 494it [13:26,  2.15s/it]
#
#
# 495it [13:30,  2.75s/it]
#
#
# 496it [13:31,  2.38s/it]
#
#
# 497it [13:33,  2.23s/it]
#
#
# 498it [13:35,  2.08s/it]
#
#
# 499it [13:36,  1.85s/it]
#
#
# 500it [13:38,  1.82s/it]
#
#
# 501it [13:40,  2.00s/it]
#
#
# 502it [13:42,  1.88s/it]
#
#
# 503it [13:43,  1.73s/it]
#
#
# 504it [13:45,  1.59s/it]
#
#
# 505it [13:48,  2.16s/it]
#
#
# 506it [13:50,  2.25s/it]
#
#
# 507it [13:52,  2.10s/it]
#
#
# 508it [13:53,  1.85s/it]
#
#
# 509it [13:55,  1.68s/it]
#
#
# 510it [13:56,  1.57s/it]
#
#
# 511it [13:57,  1.48s/it]
#
#
# 512it [13:59,  1.53s/it]
#
#
# 513it [14:00,  1.48s/it]
#
#
# 514it [14:02,  1.51s/it]
#
#
# 515it [14:07,  2.47s/it]
#
#
# 516it [14:08,  2.12s/it]
#
#
# 517it [14:10,  2.08s/it]
#
#
# 518it [14:12,  2.02s/it]
#
#
# 519it [14:13,  1.81s/it]
#
#
# 520it [14:14,  1.63s/it]
#
#
# 521it [14:16,  1.56s/it]
#
#
# 522it [14:18,  1.80s/it]
#
#
# 523it [14:19,  1.67s/it]
#
#
# 524it [14:21,  1.61s/it]
#
#
# 525it [14:23,  1.72s/it]
#
#
# 526it [14:24,  1.63s/it]
#
#
# 527it [14:26,  1.60s/it]
#
#
# 528it [14:27,  1.49s/it]
#
#
# 529it [14:28,  1.38s/it]
#
#
# 530it [14:29,  1.33s/it]
#
#
# 531it [14:31,  1.31s/it]
#
#
# 532it [14:32,  1.32s/it]
#
#
# 533it [14:33,  1.21s/it]
#
#
# 534it [14:34,  1.28s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 535it [14:35,  1.04it/s]
#
#
# 536it [14:36,  1.03s/it]
#
#
# 537it [14:37,  1.18s/it]
#
#
# 538it [14:39,  1.25s/it]
#
#
# 539it [14:40,  1.21s/it]
#
#
# 540it [14:43,  1.67s/it]
#
#
# 541it [14:44,  1.54s/it]
#
#
# 542it [14:45,  1.32s/it]
#
#
# 543it [14:46,  1.31s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 544it [14:46,  1.02it/s]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 545it [14:46,  1.31it/s]
#
#
# 547it [14:47,  1.81it/s]
#
#
# 548it [14:47,  2.39it/s]
#
#
# 550it [14:47,  3.19it/s]
#
#
# 552it [14:47,  4.19it/s]
#
#
# 554it [14:47,  5.37it/s]
#
#
# 556it [14:50,  1.91it/s]
#
#
# 557it [14:52,  1.08s/it]
#
#
# 558it [14:53,  1.11s/it]
#
#
# 559it [14:55,  1.32s/it]
#
#
# 560it [14:57,  1.47s/it]
#
#
# 561it [14:57,  1.11s/it]
#
#
# 562it [14:57,  1.16it/s]
#
#
# 563it [14:58,  1.53it/s]
#
#
# 564it [14:58,  2.04it/s]
#
#
# 565it [14:59,  1.34it/s]
#
#
# 566it [15:00,  1.13it/s]
#
#
# 567it [15:02,  1.06s/it]
#
#
# 568it [15:03,  1.15s/it]
#
#
# 569it [15:04,  1.17s/it]
#
#
# 570it [15:06,  1.20s/it]
#
#
# 571it [15:08,  1.43s/it]
#
#
# 572it [15:11,  1.98s/it]
#
#
# 573it [15:14,  2.32s/it]
#
#
# 574it [15:18,  2.94s/it]
#
#
# 575it [15:20,  2.56s/it]
#
#
# 576it [15:21,  2.24s/it]
#
#
# 577it [15:23,  2.05s/it]
# 578it [15:24,  1.77s/it]
#
#
# 579it [15:25,  1.55s/it]
#
#
# 580it [15:26,  1.40s/it]
#
#
# 581it [15:28,  1.54s/it]
#
#
# 582it [15:30,  1.78s/it]
#
#
# 583it [15:33,  1.91s/it]
#
#
# 584it [15:35,  2.03s/it]
#
#
# 585it [15:37,  2.05s/it]
#
#
# 586it [15:39,  1.96s/it]
#
#
# 587it [15:41,  1.90s/it]
#
#
# 588it [15:42,  1.85s/it]
#
#
# 589it [15:44,  1.71s/it]
#
#
# 590it [15:45,  1.51s/it]
#
#
# 591it [15:47,  1.73s/it]
#
#
# 592it [15:49,  1.95s/it]
#
#
# 593it [15:51,  1.94s/it]
#
#
# 594it [15:55,  2.50s/it]
#
#
# 595it [15:57,  2.35s/it]
#
#
# 596it [15:59,  2.19s/it]
#
#
# 597it [16:00,  1.96s/it]
#
#
# 598it [16:02,  1.83s/it]
#
#
# 599it [16:03,  1.70s/it]
#
#
# 600it [16:05,  1.60s/it]
#
#
# 601it [16:06,  1.59s/it]
#
#
# 602it [16:08,  1.62s/it]
#
#
# 603it [16:10,  1.59s/it]
#
#
# 604it [16:13,  2.30s/it]
#
#
# 605it [16:15,  2.06s/it]
#
#
# 606it [16:17,  1.99s/it]
#
#
# 607it [16:19,  1.98s/it]
#
#
# 608it [16:20,  1.76s/it]
#
#
# 609it [16:21,  1.61s/it]
#
#
# 610it [16:23,  1.65s/it]
#
#
# 611it [16:25,  1.78s/it]
#
#
# 612it [16:26,  1.66s/it]
#
#
# 613it [16:29,  2.03s/it]
#
#
# 614it [16:33,  2.46s/it]
#
#
# 615it [16:35,  2.40s/it]
#
#
# 616it [16:39,  2.73s/it]
#
#
# 617it [16:40,  2.35s/it]
#
#
# 618it [16:42,  2.12s/it]
#
#
# 619it [16:43,  1.88s/it]
#
#
# 620it [16:44,  1.69s/it]
#
#
# 621it [16:46,  1.75s/it]
#
#
# 622it [16:47,  1.65s/it]
#
#
# 623it [16:49,  1.64s/it]
#
#
# 624it [16:54,  2.73s/it]
#
#
# 625it [16:56,  2.32s/it]
#
#
# 626it [16:57,  2.14s/it]
#
#
# 627it [16:59,  2.01s/it]
#
#
# 628it [17:01,  1.84s/it]
#
#
# 629it [17:02,  1.62s/it]
#
#
# 630it [17:03,  1.49s/it]
#
#
# 631it [17:06,  1.91s/it]
#
#
# 632it [17:08,  1.93s/it]
#
#
# 633it [17:10,  1.98s/it]
#
#
# 634it [17:11,  1.83s/it]
#
#
# 635it [17:13,  1.70s/it]
#
#
# 636it [17:14,  1.64s/it]
#
#
# 637it [17:15,  1.52s/it]
#
#
# 638it [17:17,  1.41s/it]
#
#
# 639it [17:18,  1.50s/it]
#
#
# 640it [17:21,  1.77s/it]
#
#
# 641it [17:22,  1.64s/it]
#
#
# 642it [17:23,  1.47s/it]
#
#
# 643it [17:25,  1.43s/it]
#
#
# 644it [17:27,  1.66s/it]
#
#
# 645it [17:28,  1.53s/it]
#
#
# 646it [17:30,  1.70s/it]
#
#
# 647it [17:31,  1.63s/it]
#
#
# 648it [17:33,  1.55s/it]
#
#
# 649it [17:34,  1.36s/it]
#
#
# 650it [17:35,  1.41s/it]
#
#
# 651it [17:36,  1.26s/it]
#
#
# 652it [17:38,  1.33s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 653it [17:38,  1.00it/s]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 654it [17:38,  1.30it/s]
#
#
# 656it [17:38,  1.78it/s]
#
#
# 657it [17:38,  2.36it/s]
#
#
# 659it [17:39,  3.17it/s]
#
#
# 661it [17:39,  4.10it/s]
#
#
# 663it [17:39,  5.25it/s]
#
#
# 665it [17:41,  1.89it/s]
#
#
# 666it [17:43,  1.20it/s]
#
#
# 667it [17:48,  1.97s/it]
#
#
# 668it [17:50,  2.03s/it]
#
#
# 669it [17:52,  2.00s/it]
#
#
# 670it [17:52,  1.47s/it]
#
#
# 671it [17:52,  1.13s/it]
#
#
# 672it [17:52,  1.19it/s]
#
#
# 673it [17:53,  1.57it/s]
#
#
# 674it [17:54,  1.19it/s]
#
#
# 675it [17:55,  1.01it/s]
#
#
# 676it [17:57,  1.13s/it]
#
#
# 677it [17:58,  1.16s/it]
#
#
# 678it [17:59,  1.14s/it]
#
#
# 679it [18:01,  1.44s/it]
#
#
# 680it [18:04,  1.71s/it]
#
#
# 681it [18:06,  1.94s/it]
#
#
# 682it [18:08,  1.98s/it]
#
#
# 683it [18:12,  2.51s/it]
#
#
# 684it [18:13,  2.20s/it]
#
#
# 685it [18:15,  2.06s/it]
#
#
# 686it [18:17,  2.17s/it]
#
#
# 687it [18:19,  1.86s/it]
#
#
# 688it [18:20,  1.57s/it]
#
#
# 689it [18:21,  1.50s/it]
#
#
# 690it [18:23,  1.62s/it]
#
#
# 691it [18:25,  1.73s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 692it [18:31,  3.19s/it]
#
#
# 693it [18:34,  3.09s/it]
#
#
# 694it [18:36,  2.66s/it]
#
#
# 695it [18:38,  2.39s/it]
#
#
# 696it [18:39,  2.18s/it]
#
#
# 697it [18:41,  1.94s/it]
#
#
# 698it [18:42,  1.66s/it]
#
#
# 699it [18:44,  1.92s/it]
#
#
# 700it [18:46,  1.91s/it]
#
#
# 701it [18:48,  1.80s/it]
#
#
# 702it [18:51,  2.31s/it]
#
#
# 703it [18:55,  2.63s/it]
#
#
# 704it [18:56,  2.42s/it]
#
#
# 705it [18:58,  2.19s/it]
#
#
# 706it [19:00,  1.96s/it]
#
#
# 707it [19:01,  1.79s/it]
#
#
# 708it [19:02,  1.64s/it]
#
#
# 709it [19:04,  1.55s/it]
#
#
# 710it [19:05,  1.56s/it]
#
#
# 711it [19:07,  1.57s/it]
#
#
# 712it [19:08,  1.58s/it]
#
#
# 713it [19:11,  1.95s/it]
#
#
# 714it [19:13,  1.81s/it]
#
#
# 715it [19:15,  1.83s/it]
#
#
# 716it [19:16,  1.74s/it]
#
#
# 717it [19:17,  1.61s/it]
#
#
# 718it [19:19,  1.56s/it]
#
#
# 719it [19:20,  1.46s/it]
#
#
# 720it [19:22,  1.76s/it]
#
#
# 721it [19:25,  1.86s/it]
#
#
# 722it [19:26,  1.67s/it]
#
#
# 723it [19:32,  2.96s/it]
#
#
# 724it [19:34,  2.73s/it]
#
#
# 725it [19:36,  2.62s/it]
#
#
# 726it [19:38,  2.22s/it]
#
#
# 727it [19:39,  2.02s/it]
#
#
# 728it [19:40,  1.78s/it]
#
#
# 729it [19:43,  2.09s/it]
#
#
# 730it [19:45,  2.06s/it]
#
#
# 731it [19:48,  2.42s/it]
#
#
# 732it [19:50,  2.30s/it]
#
#
# 733it [19:55,  2.83s/it]
#
#
# 734it [19:56,  2.38s/it]
#
#
# 735it [19:58,  2.17s/it]
#
#
# 736it [20:01,  2.45s/it]
#
#
# 737it [20:02,  2.12s/it]
#
#
# 738it [20:03,  1.86s/it]
#
#
# 739it [20:05,  1.92s/it]
#
#
# 740it [20:07,  1.90s/it]
#
#
# 741it [20:09,  1.81s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 742it [20:15,  3.07s/it]
#
#
# 743it [20:21,  3.89s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 744it [20:25,  4.19s/it]
#
#
# 745it [20:27,  3.38s/it]
#
#
# 746it [20:28,  2.74s/it]
#
#
# 747it [20:29,  2.26s/it]
#
#
# 748it [20:31,  1.98s/it]
#
#
# 749it [20:32,  1.69s/it]
#
#
# 750it [20:33,  1.57s/it]
#
#
# 751it [20:34,  1.40s/it]
#
#
# 752it [20:35,  1.27s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 753it [20:35,  1.04it/s]
#
#
# 754it [20:36,  1.04s/it]
#
#
# 755it [20:38,  1.12s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 756it [20:42,  2.13s/it]
#
#
# 757it [20:43,  1.83s/it]
#
#
# 758it [20:44,  1.56s/it]
#
#
# 759it [20:50,  2.77s/it]
#
#
# 760it [20:51,  2.17s/it]
#
#
# 761it [20:54,  2.47s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 762it [20:54,  1.79s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 763it [20:54,  1.33s/it]
#
#
# 765it [20:54,  1.05it/s]
#
#
# 766it [20:54,  1.43it/s]
#
#
# 768it [20:55,  1.94it/s]
#
#
# 769it [20:55,  2.55it/s]
#
#
# 771it [20:55,  3.39it/s]
#
#
# 773it [20:56,  2.56it/s]
#
#
# 774it [20:58,  1.41it/s]
#
#
# 775it [20:59,  1.11it/s]
#
#
# 776it [21:00,  1.04s/it]
#
#
# 777it [21:03,  1.49s/it]
#
#
# 778it [21:05,  1.74s/it]
#
#
# 779it [21:05,  1.29s/it]
#
#
# 780it [21:06,  1.02it/s]
#
#
# 781it [21:06,  1.37it/s]
#
#
# 782it [21:06,  1.83it/s]
#
#
# 783it [21:07,  1.28it/s]
#
#
# 784it [21:09,  1.04it/s]
#
#
# 785it [21:10,  1.11s/it]
#
#
# 786it [21:12,  1.36s/it]
#
#
# 787it [21:13,  1.29s/it]
#
#
# 788it [21:15,  1.32s/it]
#
#
# 789it [21:16,  1.47s/it]
#
#
# 790it [21:23,  3.03s/it]
#
#
# 791it [21:25,  2.67s/it]
#
#
# 792it [21:29,  3.22s/it]
#
#
# 793it [21:31,  2.69s/it]
#
#
# 794it [21:33,  2.57s/it]
#
#
# 795it [21:35,  2.29s/it]
#
#
# 796it [21:36,  1.94s/it]
#
#
# 797it [21:37,  1.74s/it]
#
#
# 798it [21:38,  1.54s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 799it [21:45,  3.07s/it]
#
#
# 800it [21:48,  3.02s/it]
#
#
# 801it [21:50,  2.71s/it]
#
#
# 802it [21:53,  2.98s/it]
#
#
# 803it [21:55,  2.57s/it]
#
#
# 804it [21:57,  2.33s/it]
#
#
# 805it [21:58,  2.15s/it]
#
#
# 806it [22:00,  1.87s/it]
#
#
# 807it [22:01,  1.65s/it]
#
#
# 808it [22:02,  1.47s/it]
#
#
# 809it [22:04,  1.59s/it]
#
#
# 810it [22:05,  1.59s/it]
#
#
# 811it [22:08,  1.92s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 812it [22:17,  3.96s/it]
#
#
# 813it [22:19,  3.31s/it]
#
#
# 814it [22:20,  2.85s/it]
#
#
# 815it [22:22,  2.39s/it]
#
#
# 816it [22:23,  2.10s/it]
#
#
# 817it [22:25,  1.92s/it]
#
#
# 818it [22:26,  1.91s/it]
#
#
# 819it [22:29,  2.07s/it]
#
#
# 820it [22:30,  1.84s/it]
#
#
# 821it [22:32,  1.89s/it]
#
#
# 822it [22:34,  1.99s/it]
#
#
# 823it [22:36,  1.82s/it]
#
#
# 824it [22:38,  1.81s/it]
#
#
# 825it [22:39,  1.68s/it]
#
#
# 826it [22:40,  1.56s/it]
#
#
# 827it [22:42,  1.51s/it]
#
#
# 828it [22:43,  1.42s/it]
#
#
# 829it [22:44,  1.47s/it]
#
#
# 830it [22:46,  1.43s/it]
#
#
# 831it [22:48,  1.55s/it]
#
#
# 832it [22:50,  1.89s/it]
#
#
# 833it [22:52,  1.87s/it]
#
#
# 834it [22:54,  1.84s/it]
#
#
# 835it [22:55,  1.67s/it]
#
#
# 836it [22:56,  1.55s/it]
#
#
# 837it [23:00,  2.29s/it]
#
#
# 838it [23:02,  2.09s/it]
#
#
# 839it [23:04,  1.95s/it]
#
#
# 840it [23:06,  2.15s/it]
#
#
# 841it [23:09,  2.40s/it]
#
#
# 842it [23:12,  2.38s/it]
#
#
# 843it [23:13,  2.05s/it]
#
#
# 844it [23:15,  1.93s/it]
#
#
# 845it [23:16,  1.84s/it]
#
#
# 846it [23:18,  1.70s/it]
#
#
# 847it [23:19,  1.59s/it]
#
#
# 848it [23:21,  1.77s/it]
#
#
# 849it [23:28,  3.21s/it]
#
#
# 850it [23:30,  2.82s/it]
#
#
# 851it [23:32,  2.55s/it]
#
#
# 852it [23:33,  2.38s/it]
#
#
# 853it [23:35,  2.07s/it]
#
#
# 854it [23:36,  1.89s/it]
#
#
# 855it [23:38,  1.70s/it]
#
#
# 856it [23:39,  1.56s/it]
#
#
# 857it [23:40,  1.49s/it]
#
#
# 858it [23:43,  1.92s/it]
#
#
# 859it [23:44,  1.74s/it]
#
#
# 860it [23:46,  1.73s/it]
#
#
# 861it [23:47,  1.61s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 862it [23:48,  1.19s/it]
#
#
# 863it [23:49,  1.20s/it]
#
#
# 864it [23:50,  1.21s/it]
#
#
# 865it [23:52,  1.29s/it]
#
#
# 866it [23:53,  1.25s/it]
#
#
# 867it [23:54,  1.23s/it]
#
#
# 868it [23:55,  1.20s/it]
#
#
# 869it [23:56,  1.13s/it]
#
#
# 870it [23:57,  1.24s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 871it [23:58,  1.08it/s]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 872it [23:58,  1.38it/s]
#
#
# 874it [23:58,  1.90it/s]
#
#
# 875it [23:58,  2.50it/s]
#
#
# 877it [23:58,  3.34it/s]
#
#
# 879it [23:58,  4.39it/s]
#
#
# 881it [23:59,  5.61it/s]
#
#
# 883it [24:01,  2.09it/s]
#
#
# 884it [24:02,  1.34it/s]
#
#
# 885it [24:03,  1.14it/s]
#
#
# 886it [24:05,  1.01it/s]
#
#
# 887it [24:07,  1.33s/it]
#
#
# 888it [24:07,  1.01s/it]
#
#
# 889it [24:07,  1.27it/s]
#
#
# 890it [24:08,  1.64it/s]
#
#
# 891it [24:08,  2.17it/s]
#
#
# 892it [24:09,  1.39it/s]
#
#
# 893it [24:10,  1.17it/s]
#
#
# 894it [24:12,  1.03s/it]
#
#
# 895it [24:13,  1.17s/it]
#
#
# 896it [24:14,  1.19s/it]
#
#
# 897it [24:16,  1.28s/it]
#
#
# 898it [24:17,  1.37s/it]
#
#
# 899it [24:21,  2.03s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 900it [24:25,  2.67s/it]
#
#
# 901it [24:25,  1.95s/it]
#
#
# 902it [24:27,  1.79s/it]
#
#
# 903it [24:28,  1.70s/it]
# 904it [24:30,  1.61s/it]
#
#
# 905it [24:31,  1.46s/it]
#
#
# 906it [24:32,  1.32s/it]
#
#
# 907it [24:33,  1.24s/it]
#
#
# 908it [24:35,  1.42s/it]
#
#
# 909it [24:37,  1.74s/it]
#
#
# 910it [24:40,  2.16s/it]
#
#
# 911it [24:44,  2.51s/it]
#
#
# 912it [24:45,  2.21s/it]
#
#
# 913it [24:47,  2.07s/it]
#
#
# 914it [24:49,  1.96s/it]
#
#
# 915it [24:50,  1.79s/it]
#
#
# 916it [24:51,  1.59s/it]
#
#
# 917it [24:52,  1.46s/it]
#
#
# 918it [24:55,  1.88s/it]
#
#
# 919it [24:57,  1.86s/it]
#
#
# 920it [24:59,  1.97s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 921it [25:07,  3.66s/it]
#
#
# 922it [25:09,  3.11s/it]
#
#
# 923it [25:11,  3.00s/it]
#
#
# 924it [25:13,  2.53s/it]
#
#
# 925it [25:14,  2.18s/it]
#
#
# 926it [25:15,  1.91s/it]
#
#
# 927it [25:17,  1.69s/it]
#
#
# 928it [25:19,  1.80s/it]
#
#
# 929it [25:25,  3.04s/it]
#
#
# 930it [25:27,  2.79s/it]
#
#
# 931it [25:29,  2.70s/it]
#
#
# 932it [25:31,  2.32s/it]
#
#
# 933it [25:33,  2.16s/it]
#
#
# 934it [25:34,  1.99s/it]
#
#
# 935it [25:35,  1.77s/it]
#
#
# 936it [25:37,  1.66s/it]
#
#
# 937it [25:38,  1.57s/it]
#
#
# 938it [25:40,  1.59s/it]
#
#
# 939it [25:41,  1.51s/it]
#
#
# 940it [25:43,  1.67s/it]
#
#
# 941it [25:47,  2.44s/it]
#
#
# 942it [25:49,  2.29s/it]
#
#
# 943it [25:51,  2.17s/it]
#
#
# 944it [25:52,  1.89s/it]
#
#
# 945it [25:55,  1.95s/it]
#
#
# 946it [25:56,  1.86s/it]
#
#
# 947it [25:58,  1.95s/it]
#
#
# 948it [26:00,  1.85s/it]
#
#
# 949it [26:01,  1.71s/it]
#
#
# 950it [26:03,  1.78s/it]
#
#
# 951it [26:06,  2.07s/it]
#
#
# 952it [26:07,  1.87s/it]
#
#
# 953it [26:09,  1.82s/it]
#
#
# 954it [26:11,  1.77s/it]
#
#
# 955it [26:13,  1.97s/it]
#
#
# 956it [26:15,  2.01s/it]
#
#
# 957it [26:17,  1.89s/it]
#
#
# 958it [26:19,  1.82s/it]
#
#
# 959it [26:21,  1.95s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 960it [26:27,  3.34s/it]
#
#
# 961it [26:29,  2.73s/it]
#
#
# 962it [26:31,  2.71s/it]
#
#
# 963it [26:33,  2.36s/it]
#
#
# 964it [26:34,  2.03s/it]
#
#
# 965it [26:35,  1.77s/it]
#
#
# 966it [26:36,  1.58s/it]
#
#
# 967it [26:38,  1.57s/it]
#
#
# 968it [26:40,  1.60s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#
#
#
# 969it [26:47,  3.22s/it]
#
#
# 970it [26:48,  2.66s/it]
#
#
# 971it [26:50,  2.46s/it]
#
#
# 972it [26:51,  2.08s/it]
#
#
# 973it [26:53,  1.98s/it]
#
#
# 974it [26:55,  2.06s/it]
#
#
# 975it [26:57,  2.07s/it]
#
#
# 976it [26:58,  1.73s/it]
#
#
# 977it [26:59,  1.50s/it]
#
#
# 978it [27:00,  1.35s/it]
#
#
# 979it [27:02,  1.53s/it]
#
#
# 980it [27:03,  1.46s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 981it [27:04,  1.10s/it]
#
#
# 983it [27:04,  1.26it/s]
#
#
# 984it [27:04,  1.71it/s]
#
#
# 986it [27:04,  2.34it/s]
#
#
# 988it [27:04,  3.15it/s]
#
#
# 990it [27:04,  4.12it/s]
#
#
# 992it [27:07,  1.81it/s]
#
#
# 993it [27:09,  1.02it/s]
#
#
# 994it [27:10,  1.06s/it]
#
#
# 995it [27:11,  1.15s/it]
#
#
# 996it [27:14,  1.69s/it]
#
#
# 997it [27:15,  1.26s/it]
#
#
# 998it [27:15,  1.04it/s]
#
#
# 999it [27:15,  1.40it/s]
#
#
# 1000it [27:15,  1.86it/s]
#
#
# 1001it [27:17,  1.30it/s]
#
#
# 1002it [27:18,  1.11it/s]
#
#
# 1003it [27:19,  1.08s/it]
#
#
# 1004it [27:21,  1.18s/it]
#
#
# 1005it [27:22,  1.16s/it]
#
#
# 1006it [27:24,  1.51s/it]
#
#
# 1007it [27:27,  1.96s/it]
#
#
# 1008it [27:32,  2.73s/it]
#
#
# 1009it [27:34,  2.52s/it]
#
#
# 1010it [27:34,  1.85s/it]
#
#
# 1011it [27:35,  1.74s/it]
#
#
# 1012it [27:37,  1.67s/it]
#
#
# 1013it [27:38,  1.57s/it]
#
#
# 1014it [27:39,  1.43s/it]
#
#
# 1015it [27:41,  1.38s/it]
#
#
# 1016it [27:42,  1.29s/it]
#
#
# 1017it [27:44,  1.65s/it]
#
#
# 1018it [27:47,  1.91s/it]
#
#
# 1019it [27:47,  1.45s/it]
#
#
# 1020it [27:50,  2.02s/it]
#
#
# 1021it [27:55,  2.73s/it]
#
#
# 1022it [27:57,  2.49s/it]
#
#
# 1023it [27:58,  2.26s/it]
#
#
# 1024it [28:00,  1.93s/it]
#
#
# 1025it [28:01,  1.70s/it]
#
#
# 1026it [28:02,  1.63s/it]
#
#
# 1027it [28:05,  2.01s/it]
#
#
# 1028it [28:09,  2.46s/it]
#
#
# 1029it [28:12,  2.64s/it]
#
#
# 1030it [28:14,  2.59s/it]
#
#
# 1031it [28:16,  2.33s/it]
#
#
# 1032it [28:18,  2.13s/it]
#
#
# 1033it [28:19,  1.93s/it]
#
#
# 1034it [28:21,  1.83s/it]
#
#
# 1035it [28:22,  1.66s/it]
#
#
# 1036it [28:23,  1.61s/it]
#
#
# 1037it [28:25,  1.60s/it]
#
#
# 1038it [28:29,  2.24s/it]
#
#
# 1039it [28:31,  2.21s/it]
#
#
# 1040it [28:33,  2.23s/it]
#
#
# 1041it [28:35,  1.99s/it]
#
#
# 1042it [28:36,  1.96s/it]
#
#
# 1043it [28:38,  1.90s/it]
#
#
# 1044it [28:39,  1.71s/it]
#
#
# 1045it [28:41,  1.58s/it]
#
#
# 1046it [28:42,  1.59s/it]
#
#
# 1047it [28:44,  1.64s/it]
#
#
# 1048it [28:46,  1.84s/it]
#
#
# 1049it [28:49,  1.95s/it]
#
#
# 1050it [28:51,  2.06s/it]
#
#
# 1051it [28:53,  1.92s/it]
#
#
# 1052it [28:54,  1.91s/it]
#
#
# 1053it [28:56,  1.72s/it]
#
#
# 1054it [28:57,  1.59s/it]
#
#
# 1055it [28:58,  1.47s/it]
#
#
# 1056it [29:01,  1.93s/it]
#
#
# 1057it [29:03,  1.83s/it]
#
#
# 1058it [29:05,  2.06s/it]
#
#
# 1059it [29:08,  2.07s/it]
#
#
# 1060it [29:09,  2.04s/it]
#
#
# 1061it [29:11,  1.82s/it]
#
#
# 1062it [29:12,  1.77s/it]
#
#
# 1063it [29:14,  1.74s/it]
#
#
# 1064it [29:16,  1.66s/it]
#
#
# 1065it [29:18,  1.76s/it]
#
#
# 1066it [29:19,  1.65s/it]
#
#
# 1067it [29:22,  1.92s/it]
#
#
# 1068it [29:23,  1.80s/it]
#
#
# 1069it [29:26,  2.03s/it]
#
#
# 1070it [29:30,  2.61s/it]
#
#
# 1071it [29:31,  2.26s/it]
#
#
# 1072it [29:33,  2.03s/it]
#
#
# 1073it [29:34,  1.79s/it]
#
#
# 1074it [29:35,  1.60s/it]
#
#
# 1075it [29:36,  1.44s/it]
#
#
# 1076it [29:37,  1.32s/it]
#
#
# 1077it [29:39,  1.37s/it]
#
#
# 1078it [29:39,  1.25s/it]
#
#
# 1079it [29:42,  1.55s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 1080it [29:42,  1.15s/it]
#
#
# 1081it [29:43,  1.16s/it]
#
#
# 1082it [29:45,  1.43s/it]
#
#
# 1083it [29:47,  1.41s/it]
#
#
# 1084it [29:48,  1.51s/it]
# 1085it [29:49,  1.41s/it]
#
#
# 1086it [29:52,  1.65s/it]
#
#
# 1087it [29:53,  1.45s/it]
#
#
# 1088it [29:55,  1.62s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 1089it [29:55,  1.19s/it]/home/mullin/anaconda3/envs/PAIML/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
#
# 1090it [29:55,  1.65s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 n_folds = 10
# ----> 2 avg_R2score_M, best_para_M = Matern_para_select(X_train, y_train, n_folds)
#
# Cell In[51], line 23, in Matern_para_select(X, y, n_folds)
#      21         pbar.update()
#      22 pbar.close()
# ---> 23 print("Best Param: ", params[np.argmax([avg_R2score])], " Score: ", avg_R2score[np.argmax([avg_R2score])])
#      24 print(avg_R2score)
#      25 print("______________end_____________")
#
# NameError: name 'avg_R2score' is not defined

# %% [markdown]
# ### Rational Quadratic Kernel
